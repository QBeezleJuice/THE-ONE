# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(4, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.measure(qreg_q[0], creg_c[1])

circuit.draw('text')
# Out:
#      ┌───┐┌─┐
# q_0: ┤ H ├┤M├
#      └───┘└╥┘
# q_1: ──────╫─
#            ║
# q_2: ──────╫─
#            ║
# q_3: ──────╫─
#            ║
# c: 4/══════╩═
#            1

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(4, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.measure(qreg_q[1], creg_c[1])

circuit.draw('text')
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫─┤M├
#           └───┘ ║ └╥┘
# q_2: ───────────╫──╫─
#                 ║  ║
# q_3: ───────────╫──╫─
#                 ║  ║
# c: 4/═══════════╩══╩═
#                 0  1

# %% [markdown]
# # Learning Notes: Interference & Deutsch-Jozsa Algorithm
# ## Day 5 Self-Directed Learning
#
# **Student Name:** _______Kit M. KO________
#
# **Date:** February 4, 2026
#
# **Learning Tool:** NotebookLM
#
# ---
#
# ## 🎯 MY LEARNING GOALS FOR TODAY
#
# By the end of this session, I want to understand:
# - [ ] What quantum interference is and why it matters
# - [ ] How the Z gate works
# - [ ] The H-Z-H pattern
# - [ ] What problem Deutsch-Jozsa algorithm solves
# - [ ] How Deutsch-Jozsa is faster than classical computers
#
# ---
#
# # PART 1: QUANTUM INTERFERENCE
#
# ## What is Quantum Interference?
#
# **In my own words:**
#
# [Quantum interference works by combining different quantum paths so that correct answers add together through constructive interference and incorrect ones cancel out through destructive interference. This process converts hidden phase information into a single, definite state that we can measure to solve the problem.]
#
# ---
#
# ## The Z Gate
#
# **What does the Z gate do?**
#
# [Your explanation]
#
# **Draw or describe the effect:**
#
# |0⟩ → _______________
#
# |1⟩ → _______________
#
# ---
#
# ## The H-Z-H Pattern
#
# **Step 1: First H gate does...**
#
# [Your explanation]
#
# **Step 2: Z gate does...**
#
# [Your explanation]
#
# **Step 3: Second H gate does...**
#
# [Your explanation]
#
# **The result is:**
#
# [Your explanation]
#
# ---
#
# ## Why Does This Matter?
#
# **How is interference used in quantum algorithms?**
#
# [Your explanation in 2-3 sentences]
#
# ---
#
# **Something that clicked for me about interference:**
#
# [What suddenly made sense?]
#
# ---
#
# ## ❓ Questions I Still Have About Interference
#
# 1. _______________________________________________
#
# 2. _______________________________________________
#
# 3. _______________________________________________
#
# ---
#
# # PART 2: DEUTSCH-JOZSA ALGORITHM
#
# ## The Problem It Solves
#
# **What is the mystery box problem?**
#
# [Explain in your own words: What is constant vs balanced?]
#
# **Constant function means:**
#
# [Your explanation]
#
# **Balanced function means:**
#
# [Your explanation]
#
# ---
#
# ## Classical vs Quantum Solution
#
# ### Classical Computer Approach:
#
# **How many checks does a classical computer need?**
#
# [Your answer]
#
# **Why can't it do better?**
#
# [Your explanation]
#
# ---
#
# ### Quantum Computer Approach:
#
# **How many checks does a quantum computer need?**
#
# [Your answer]
#
# **How is this possible?**
#
# [Your explanation - mention superposition, interference]
#
# ---
#
# ## How the Circuit Works
#
# **Step-by-step explanation:**
#
# **Step 1:**
#
# [What happens first?]
#
# **Step 2:**
#
# [What happens with the oracle?]
#
# **Step 3:**
#
# [What happens at the end?]
#
# **Step 4:**
#
# [What do we measure?]
#
# ---
#
# ## Understanding the Result
#
# **If we measure |00⟩, this means:**
#
# [Your explanation]
#
# **If we measure something else, this means:**
#
# [Your explanation]
#
# ---
#
# ## Real-World Connection
#
# **Why is this algorithm important even though it solves a "toy" problem?**
#
# [Your explanation - what technique does it demonstrate?]
#
# **Where is this technique used in real quantum algorithms?**
#
# [Your answer]
#
# ---
#
#
# **Something that clicked for me about Deutsch-Jozsa:**
#
# [What suddenly made sense?]
#
# ---
#
# ## ❓ Questions I Still Have About Deutsch-Jozsa
#
# 1. _______________________________________________
#
# 2. _______________________________________________
#
# 3. _______________________________________________
#
# ---
#
# # PART 3: CONNECTING THE CONCEPTS
#
# ## How Interference Powers Deutsch-Jozsa
#
# **Explain how the Deutsch-Jozsa algorithm uses interference:**
#
# [Your explanation - connect Part 1 and Part 2]
#
# ---
#
# ## Classical vs Quantum Thinking
#
# **Before learning this, I thought:**
#
# [Your answer]
#
# **Now I understand:**
#
# [Your answer]
#
# **This changes my perspective because:**
#
# [Your answer]
#
# ---
#
# # PART 4: BUILDING THE CIRCUIT
#
# ## H-Z-H Practice Circuit
#
# **I tried building this circuit:**
#
# ```
# q[0]: ──H──Z──H──M──
# ```
#
# **What I predicted would happen:**
#
# [Your prediction]
#
# **What actually happened:**
#
# [Your result]
#
# **Why this result makes sense:**
#
# [Your explanation]
#
# ---
#
# ## Deutsch-Jozsa Circuit
#
# **Did you try building a Deutsch-Jozsa circuit?**
# - [ ] Yes, I built it!
# - [ ] Not yet, but I will
#
# **If yes, what type of oracle did you build?**
# - [ ] Constant oracle
# - [ ] Balanced oracle
#
# **What result did you get?**
#
# [Your answer]
#
# ---
#
# # PART 5: KEY TAKEAWAYS
#
# ## Three Most Important Things I Learned Today
#
# ### 1.
#
# [First key takeaway]
#
# ### 2.
#
# [Second key takeaway]
#
# ### 3.
#
# [Third key takeaway]
#
# ---
# ## 📝 ADDITIONAL NOTES & DOODLES
#
# [Use this space for any drawings, diagrams, random thoughts, or "lightbulb moments"]

# %% [markdown]
# # Quantum Computing Project Proposal
#
# ---
#
# ## 📋 STUDENT INFORMATION
#
# **Name:** [Kit Marceline Kildahl-Olmedo]
#
# **Domain:** [Check one]
# - [ ] 🏥 Healthcare & Drug Discovery
# - [!] 🔐 Cybersecurity & Encryption
# - [ ] 🌱 Sustainability & Climate Solutions
#
# **Project Title:** [Create a catchy, descriptive title]
#
# **Date:** February 4, 2026
#
# ---
#
# ## 🎯 THE PROBLEM (Classical Thinking Approach)
#
# **Describe the problem you're addressing:**
#
# [Explain the problem in 3-5 sentences. What challenge exists in your chosen domain? How do classical computers currently approach it? What are the limitations?]
#
# **Example:** In drug discovery, pharmaceutical companies need to test millions of potential drug molecules to find one that works. Classical computers must test each molecule one at a time through simulations, which takes 10+ years and costs billions of dollars. Many promising treatments are never discovered because searching through all possibilities is computationally impossible.
#
# ---
#
# **Classical Computer Approach:**
# - [What steps would a classical computer take?]
# - [Why is this slow/difficult/expensive?]
# - [What's the fundamental limitation?]
#
# ---
#
# ## 🌀 QUANTUM THINKING SHIFT
#
# **How does quantum thinking change your perspective on this problem?**
#
# **Before Learning Quantum Computing:**
# [What did you think was the only way to solve this problem?]
#
# **After Learning Quantum Principles:**
# [How has your thinking shifted? What new possibilities do you see?]
#
# **Example:** Before quantum computing, I thought we had to check each drug molecule individually - there was no shortcut. After learning about superposition and interference, I realized quantum computers can test multiple molecules simultaneously and use interference to amplify the best candidates, fundamentally changing what's possible in drug discovery.
#
# ---
#
# **What becomes possible with quantum thinking that wasn't before?**
#
# [Describe 2-3 new possibilities]
#
# ---
#
# ## ⚛️ QUANTUM CONCEPTS I'LL USE
#
# **Check all quantum concepts that apply to your project and explain HOW each one connects:**
#
# ### [ ] Superposition
# **How it applies to my project:**
# [Explain how being in multiple states simultaneously helps solve your problem]
#
# **Example:** Superposition allows testing all possible drug molecules at once instead of one at a time.
#
# ---
#
# ### [ ] Entanglement
# **How it applies to my project:**
# [Explain how qubits that can't be described independently help solve your problem]
#
# **Example:** In quantum cryptography, entangled qubits ensure that any eavesdropping attempt is immediately detected because measuring one qubit affects the other.
#
# ---
#
# ### [ ] Interference
# **How it applies to my project:**
# [Explain how amplifying right answers and canceling wrong ones helps solve your problem]
#
# **Example:** Interference amplifies molecular structures with desired properties while canceling out poor candidates, reducing the search space dramatically.
#
# ---
#
# ### [ ] Deutsch-Jozsa Algorithm
# **How it applies to my project:**
# [Explain how this algorithm concept connects - even if just as a demonstration of quantum speedup]
#
# **Example:** While Deutsch-Jozsa solves a specific academic problem, it demonstrates the core principle my project uses: quantum parallelism with interference to get answers in one query instead of many.
#
# ---
#
# ## 🔬 MY PROJECT STRUCTURE
#
# ### 30% Technical Component
#
# **What I'll implement in code:**
#
# - [ ] Deutsch-Jozsa algorithm circuit
# - [ ] [Any other circuits/algorithms]
# - [ ] Simulations and visualizations
# - [ ] Run on IBM Quantum simulator
#
# **Specific circuits I'll build:**
# 1. [Circuit 1 name and purpose]
# 2. [Circuit 2 name and purpose - optional]
#
# ---
#
# ### 70% Conceptual Component
#
# **What I'll explain in detail:**
#
# - [ ] My quantum mindset shift (classical → quantum thinking)
# - [ ] How quantum principles apply to [my domain] problems
# - [ ] Classical vs quantum reasoning comparison
# - [ ] Real-world applications and impact
# - [ ] What this means for the future of [my domain]
#
# **Key explanations I'll provide:**
# 1. [Concept 1]
# 2. [Concept 2]
# 3. [Concept 3]
#
# ---
#
# ## 🌍 REAL-WORLD CONNECTION
#
# **Which companies, research labs, or organizations are working on this?**
#
# [List 2-3 companies/labs and what they're doing]
#
# **Example:**
# - IBM Quantum working on molecular simulation for drug discovery
# - Google Quantum AI exploring quantum chemistry applications
# - Moderna partnering with quantum computing companies for vaccine development
#
# ---
#
# **What's the potential impact if this succeeds?**
#
# [Describe the real-world impact in 2-3 sentences]
#
# ---
#
# ## 📚 WHAT I STILL NEED TO LEARN
#
# **Questions I have:**
# 1. [Question 1]
# 2. [Question 2]
# 3. [Question 3]
#
# **What I'll ask AI/NotebookLM about:**
# - [Topic 1 to research]
# - [Topic 2 to research]
# - [Topic 3 to research]
#
# **Resources I need:**
# - [ ] Tutorial on [specific concept]
# - [ ] Example code for [specific algorithm]
# - [ ] Research paper or article about [specific application]
#
# ---
#
# ## 🎤 PRESENTATION PLAN (Day 9)
#
#
#
# 1. **The Problem** (30 seconds)
#    - [Quick problem description]
#
# 2. **Classical vs Quantum Approach** (1 minute)
#    - [How thinking shifts]
#
# 3. **Quantum Concepts in Action** (2 minutes)
#    - [Demonstrate understanding with examples]
#
# 4. **Technical Demo** (1 minute)
#    - [Show my Deutsch-Jozsa circuit or other implementation]
#
# 5. **Impact & Future** (30 seconds)
#    - [Why this matters]
#
#
# ---
#
# ## 💭 PERSONAL REFLECTION
#
# **What excites me most about this project?**
#
# [Your answer]
#
# **What's the biggest challenge I expect?**
#
# [Your answer]
#
# **How does this project represent my quantum thinking journey?**
#
# [Your answer]
#
# ---
#
# ## 📝 NOTES & IDEAS
#
# **Additional thoughts, ideas, or things to remember:**
#
# [Use this space for brainstorming, random ideas, or important notes]
#
# ---
#
# **Last Updated:** [Date]
#
# **Status:** [In Progress / Ready for Review / Finalized]
